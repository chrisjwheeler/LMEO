# %%
from methods import *
lm = LMEO()

# %% [markdown]
# ### We will compare the ranking from the hotels.
#
# I would like to identify patterns in the ranking. Assuming that the rankings are perfect then there shouldnt be any patterns.
# At which point you will have to study what it similar about the hotels.
#
# Get all the lists.
#
# Doesnt appear to be much of significance similar.
#
# Think about the following:
# - What do the top hotels have in common?
#     - Is it correlated with price/reviews/length of time/ anything else.
#
# You shoudl then check how robust the rankings are to prompts.

# %%
Exeter_words =  [['Abode', 'ABode']] + 'Vin Mercure Holiday Queens Gate Devon Magdalen South Globe Rougemont Buckerel'.split()
Bristol_words =  ['Marriott','Gainsborough','Hilton','Mercure', 'arbour' ,'Radisson', 'Avon', 'DoubleTree', 'Berkeley', 'ibis', 'Future','ztec', 'gabel', ]
London_words = 'Savoy Langham Ritz Clarid hangri Dorchest Shard Rose Royal'.split()
Manchester_words = 'Gotham rincipal idland adisson ilton'.split() + ['Meli', 'inn', 'INN', 'Inn']
Newcastle_words = 'Crowne Vin County Dene Sandman Indigo Hilton Jury'.split()
Brighton_words = 'Drake Vin Jurys Artist Queens Grand TheBrighton'.split()
Birmingham_words = 'ACHotel BirminghamCityCentre Vin Cube dgbaston Grand Staying Indigo'.split()
Leeds_words = 'Dakota DoubleTree Malmaison Marrio Quebecs Radisson Queen Thorpe Park bisSt Cosmo'.split()
Liverpool_words = 'Double HopeS James Pullman Liner Titanic Indigo Richmond Malmaison'.split()

# %%
cities = ['Exeter', 'Bristol', 'London', 'Manchester', 'Newcastle', 'Brighton', 'Birmingham', 'Leeds', 'Liverpool']
words = [Exeter_words, Bristol_words, London_words, Manchester_words, Newcastle_words, Brighton_words, Birmingham_words, Leeds_words, Liverpool_words]

# %%
filter_amount = 25
key = None
word_city_zip = zip(cities, words)
for city, words in word_city_zip:
    print(city)
    Static.plot_from_ranks_target(f'.\\pickles\\ranks_{city}.pkl', words, filter_amount, key)
# Out:
# Exeter
# Bristol
# London
# Manchester
# Newcastle
# Brighton
# Birmingham
# Leeds
# Liverpool
